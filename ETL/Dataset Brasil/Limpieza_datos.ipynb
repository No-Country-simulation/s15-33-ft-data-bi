# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def repeats(df, column_name):
    # Verificar si la columna existe en el DataFrame
    if column_name not in df.columns:
        print(f"La columna '{column_name}' no existe en el DataFrame.")
        return
    
    # Convertir la columna al tipo de dato entero (si es posible)
    try:
        df[column_name] = df[column_name].astype(int)
    except ValueError:
        print(f"No se pudo convertir la columna '{column_name}' a tipo de dato entero.")
        return
    
    # Contar la frecuencia de cada valor en la columna
    counts = df[column_name].value_counts()
    # Seleccionar los valores que se repiten
    repeated_values = counts[counts > 1].index.tolist()
    
    if not repeated_values:
        print(f"No hay valores repetidos en la columna '{column_name}'.")
        return
    
    # Imprimir información de los valores repetidos
    print(f"Valores repetidos en la columna '{column_name}':")
    for value in repeated_values:
        # Encontrar las filas que contienen el valor repetido
        rows = df.index[df[column_name] == value].tolist()
        print(f"  Valor '{value}' se repite {counts[value]} veces en las filas {rows}")

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
df_clubs = pd.read_csv('./Data/liga brasil/clubs.csv')
df_clubs.head()
# Out:
#    total_market_value  squad_size  average_age  foreigners_number  \
# 0               95.65          29         27.9                  9
# 1              109.95          35         27.9                  4
# 2               35.45          38         27.0                  8
# 3               69.90          35         26.7                 10
# 4              109.30          34         24.8                  6
#
#    foreigners_percentage  national_team_players  \
# 0                  0.310                      5
# 1                  0.114                      2
# 2                  0.211                      3
# 3                  0.286                      4
# 4                  0.176                      2
#
#                      stadium_name  stadium_seats  net_transfer_record  \
# 0               Estádio Beira-Rio          50848                 4.09
# 1  Estádio Jornalista Mário Filho          82238                 4.72
# 2         Estádio Urbano Caldeira          16068                42.33
# 3  Estádio Olímpico Nilton Santos          46931                14.33
# 4               Neo Química Arena          49205                38.03
#
#                             code                             name  club_id
# 0  sc-internacional-porto-alegre         Sport Club Internacional     6600
# 1      fluminense-rio-de-janeiro         Fluminense Football Club     2462
# 2                      fc-santos                        Santos FC      221
# 3        botafogo-rio-de-janeiro    Botafogo de Futebol e Regatas      537
# 4          corinthians-sao-paulo  Sport Club Corinthians Paulista      199

# %%
df_clubs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_market_value     20 non-null     float64
#  1   squad_size             20 non-null     int64
#  2   average_age            20 non-null     float64
#  3   foreigners_number      20 non-null     int64
#  4   foreigners_percentage  20 non-null     float64
#  5   national_team_players  20 non-null     int64
#  6   stadium_name           20 non-null     object
#  7   stadium_seats          20 non-null     int64
#  8   net_transfer_record    20 non-null     float64
#  9   code                   20 non-null     object
#  10  name                   20 non-null     object
#  11  club_id                20 non-null     int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.0+ KB

# %% [markdown]
# Valores que se repiten por columna

# %%
repeats(df_clubs,'club_id')
# Out:
# No hay valores repetidos en la columna 'club_id'.

# %%
# Seleccionar las columnas con datos numéricos
numeric_columns = df_clubs.select_dtypes(include='number')

# Imprimir el valor máximo y mínimo de cada columna numérica
for column in numeric_columns.columns:
    max_value = numeric_columns[column].max()
    min_value = numeric_columns[column].min()
    print(f'Columna {column}:')
    print(f'  Valor máximo: {max_value}')
    print(f'  Valor mínimo: {min_value}')
# Out:
# Columna total_market_value:
#   Valor máximo: 219.95
#   Valor mínimo: 14.65
# Columna squad_size:
#   Valor máximo: 38
#   Valor mínimo: 27
# Columna average_age:
#   Valor máximo: 28.3
#   Valor mínimo: 24.1
# Columna foreigners_number:
#   Valor máximo: 10
#   Valor mínimo: 1
# Columna foreigners_percentage:
#   Valor máximo: 0.31
#   Valor mínimo: 0.03
# Columna national_team_players:
#   Valor máximo: 9
#   Valor mínimo: 0
# Columna stadium_seats:
#   Valor máximo: 82238
#   Valor mínimo: 14525
# Columna net_transfer_record:
#   Valor máximo: 995.0
#   Valor mínimo: 0.0
# Columna club_id:
#   Valor máximo: 28022
#   Valor mínimo: 199

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
df_game_lineups = pd.read_csv('./Data/liga brasil/game_lineups.csv')
df_game_lineups.head()
# Out:
#    player_number     player_name  is_team_captain     position  club  \
# 0              1           Bento                0   Goalkeeper  home
# 1             15   Mateo Gamarra                0  Centre-Back  home
# 2              4    Kaique Rocha                0  Centre-Back  home
# 3             37  Lucas Esquivel                0    Left-Back  home
# 4             29  Leonardo Godoy                0   Right-Back  home
#
#   formation  game_id  player_id
# 0   4-2-3-1  4316294     691906
# 1   4-2-3-1  4316294     661245
# 2   4-2-3-1  4316294     633377
# 3   4-2-3-1  4316294     829969
# 4   4-2-3-1  4316294     369556

# %%
df_game_lineups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   player_number    2380 non-null   int64
#  1   player_name      2380 non-null   object
#  2   is_team_captain  2380 non-null   int64
#  3   position         2380 non-null   object
#  4   club             2380 non-null   object
#  5   formation        2380 non-null   object
#  6   game_id          2380 non-null   int64
#  7   player_id        2380 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 148.9+ KB

# %%
# Seleccionar las columnas con datos numéricos
numeric_columns = df_game_lineups.select_dtypes(include='number')

# Imprimir el valor máximo y mínimo de cada columna numérica
for column in numeric_columns.columns:
    max_value = numeric_columns[column].max()
    min_value = numeric_columns[column].min()
    print(f'Columna {column}:')
    print(f'  Valor máximo: {max_value}')
    print(f'  Valor mínimo: {min_value}')
# Out:
# Columna player_number:
#   Valor máximo: 99
#   Valor mínimo: 1
# Columna is_team_captain:
#   Valor máximo: 1
#   Valor mínimo: 0
# Columna game_id:
#   Valor máximo: 4316315
#   Valor mínimo: 4316187
# Columna player_id:
#   Valor máximo: 1260621
#   Valor mínimo: 10471

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
df_games = pd.read_csv('./Data/liga brasil/games.csv')
df_games.head()
# Out:
#    game_id  home_club_position  away_club_position  result  matchday  \
# 0  4316187                   5                  18  (2, 1)         1
# 1  4316310                   3                  16  (2, 0)         6
# 2  4316295                  20                   6  (0, 2)         5
# 3  4316291                   3                   2  (1, 2)         5
# 4  4316294                   1                  17  (1, 0)         5
#
#          date                         stadium  attendance  \
# 0  2024-04-13               Estádio Beira-Rio       22045
# 1  2024-05-11  Estádio Jornalista Mário Filho       56829
# 2  2024-05-05                  Arena Pantanal       10781
# 3  2024-05-05  Estádio Olímpico Nilton Santos       22685
# 4  2024-05-05                     Ligga Arena       31192
#
#                         referee        home_manager   away_manager  \
# 0  Rodrigo Jose Pereira de Lima      Eduardo Coudet   Rogério Ceni
# 1                  Ramon Abatti                Tite  Toni Oliveira
# 2         Bruno Arleu de Araújo  Ricardo Colbachini  Abel Ferreira
# 3          Rafael Rodrigo Klein         Artur Jorge   Rogério Ceni
# 4              Anderson Daronco                Cuca   Rafael Paiva
#
#    home_club_id  away_club_id
# 0          6600         10010
# 1           614           199
# 2         28022          1023
# 3           537         10010
# 4           679           978

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   game_id             52 non-null     int64
#  1   home_club_position  52 non-null     int64
#  2   away_club_position  52 non-null     int64
#  3   result              52 non-null     object
#  4   matchday            52 non-null     int64
#  5   date                52 non-null     object
#  6   stadium             52 non-null     object
#  7   attendance          52 non-null     int64
#  8   referee             52 non-null     object
#  9   home_manager        52 non-null     object
#  10  away_manager        52 non-null     object
#  11  home_club_id        52 non-null     int64
#  12  away_club_id        52 non-null     int64
# dtypes: int64(7), object(6)
# memory usage: 5.4+ KB

# %%
repeats(df_games,'game_id')
# Out:
# No hay valores repetidos en la columna 'game_id'.

# %%
# Seleccionar las columnas con datos numéricos
numeric_columns = df_games.select_dtypes(include='number')

# Imprimir el valor máximo y mínimo de cada columna numérica
for column in numeric_columns.columns:
    max_value = numeric_columns[column].max()
    min_value = numeric_columns[column].min()
    print(f'Columna {column}:')
    print(f'  Valor máximo: {max_value}')
    print(f'  Valor mínimo: {min_value}')
# Out:
# Columna game_id:
#   Valor máximo: 4316315
#   Valor mínimo: 4316187
# Columna home_club_position:
#   Valor máximo: 20
#   Valor mínimo: 1
# Columna away_club_position:
#   Valor máximo: 20
#   Valor mínimo: 1
# Columna matchday:
#   Valor máximo: 6
#   Valor mínimo: 1
# Columna attendance:
#   Valor máximo: 56829
#   Valor mínimo: 5032
# Columna home_club_id:
#   Valor máximo: 28022
#   Valor mínimo: 199
# Columna away_club_id:
#   Valor máximo: 28022
#   Valor mínimo: 199

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
df_players = pd.read_csv('./Data/liga brasil/players.csv')
df_players.head()
# Out:
#                name  number date_of_birth  age  height citizenship  \
# 0              rene       6    1992-09-14   31    1.74      Brazil
# 1  joao dalla corte       0    2006-06-07   17    1.78      Brazil
# 2           dalbert      29    1993-09-08   30    1.81      Brazil
# 3      felipe motta      52    2003-08-03   20    1.87      Brazil
# 4        igor gomes       3    2001-03-06   23    1.85      Brazil
#
#                  position   foot      joined contract_expires outfitter  \
# 0    Defender - Left-Back   left  2022-04-11       2024-12-31    adidas
# 1  Defender - Centre-Back   left  2024-01-01       2025-12-31       NaN
# 2    Defender - Left-Back   left  2024-04-17       2024-12-31       NaN
# 3  Defender - Centre-Back    NaN  2024-02-23       2025-06-30       NaN
# 4  Defender - Centre-Back  right  2022-08-05       2024-12-31      Nike
#
#    player_id  club_id country_of_birth        city_of_birth
# 0     212209     6600           Brazil                Picos
# 1    1004735     6600           Brazil  Encruzilhada do Sul
# 2     312862     6600           Brazil          Barra Mansa
# 3    1083638     6600           Brazil       Rio de Janeiro
# 4     689640     6600           Brazil          Barra Mansa

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1080 non-null   object
#  1   number            1080 non-null   int64
#  2   date_of_birth     1080 non-null   object
#  3   age               1080 non-null   int64
#  4   height            1028 non-null   float64
#  5   citizenship       1080 non-null   object
#  6   position          1080 non-null   object
#  7   foot              1017 non-null   object
#  8   joined            1008 non-null   object
#  9   contract_expires  900 non-null    object
#  10  outfitter         590 non-null    object
#  11  player_id         1080 non-null   int64
#  12  club_id           1080 non-null   int64
#  13  country_of_birth  1009 non-null   object
#  14  city_of_birth     1009 non-null   object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 126.7+ KB

# %%
repeats(df_players,'player_id')
# Out:
# Valores repetidos en la columna 'player_id':
#   Valor '212209' se repite 2 veces en las filas [0, 656]
#   Valor '89701' se repite 2 veces en las filas [31, 646]
#   Valor '982551' se repite 2 veces en las filas [23, 639]
#   Valor '104505' se repite 2 veces en las filas [24, 641]
#   Valor '678439' se repite 2 veces en las filas [25, 640]
#   Valor '552242' se repite 2 veces en las filas [26, 643]
#   Valor '689507' se repite 2 veces en las filas [27, 642]
#   Valor '257740' se repite 2 veces en las filas [28, 645]
#   Valor '277335' se repite 2 veces en las filas [29, 644]
#   Valor '815384' se repite 2 veces en las filas [30, 647]
#   Valor '103674' se repite 2 veces en las filas [32, 649]
#   Valor '982552' se repite 2 veces en las filas [21, 638]
#   Valor '689505' se repite 2 veces en las filas [33, 650]
#   Valor '687359' se repite 2 veces en las filas [34, 648]
#   Valor '213606' se repite 2 veces en las filas [36, 652]
#   Valor '275381' se repite 2 veces en las filas [37, 653]
#   Valor '102740' se repite 2 veces en las filas [38, 654]
#   Valor '980767' se repite 2 veces en las filas [39, 657]
#   Valor '749557' se repite 2 veces en las filas [40, 655]
#   Valor '1004735' se repite 2 veces en las filas [1, 659]
#   Valor '236202' se repite 2 veces en las filas [22, 637]
#   Valor '119905' se repite 2 veces en las filas [35, 651]
#   Valor '213368' se repite 2 veces en las filas [20, 636]
#   Valor '417084' se repite 2 veces en las filas [10, 667]
#   Valor '312862' se repite 2 veces en las filas [2, 658]
#   Valor '788362' se repite 2 veces en las filas [19, 635]
#   Valor '1083638' se repite 2 veces en las filas [3, 660]
#   Valor '689640' se repite 2 veces en las filas [4, 661]
#   Valor '119434' se repite 2 veces en las filas [6, 664]
#   Valor '643750' se repite 2 veces en las filas [7, 663]
#   Valor '869437' se repite 2 veces en las filas [8, 665]
#   Valor '428783' se repite 2 veces en las filas [9, 666]
#   Valor '45319' se repite 2 veces en las filas [5, 662]
#   Valor '813038' se repite 2 veces en las filas [11, 669]
#   Valor '264014' se repite 2 veces en las filas [13, 670]
#   Valor '982549' se repite 2 veces en las filas [14, 631]
#   Valor '560417' se repite 2 veces en las filas [15, 630]
#   Valor '139503' se repite 2 veces en las filas [16, 633]
#   Valor '738507' se repite 2 veces en las filas [18, 634]
#   Valor '432914' se repite 2 veces en las filas [12, 668]
#   Valor '48974' se repite 2 veces en las filas [17, 632]

# %%
df_players[df_players['player_id'] == 560417]
# Out:
#        name  number date_of_birth  age  height citizenship  \
# 15   alemao      14    1998-04-01   26    1.82      Brazil
# 630  alemao      14    1998-04-01   26    1.82      Brazil
#
#                     position   foot      joined contract_expires outfitter  \
# 15   Attack - Centre-Forward  right  2023-07-17       2024-06-30      Nike
# 630  Attack - Centre-Forward  right  2023-07-17       2024-06-30      Nike
#
#      player_id  club_id country_of_birth city_of_birth
# 15      560417     6600           Brazil     Campo Erê
# 630     560417     6600           Brazil     Campo Erê

# %%
df_players[df_players['player_id'] == 89701]
# Out:
#                  name  number date_of_birth  age  height citizenship  \
# 31   charles aranguiz      20    1989-04-17   35    1.71       Chile
# 646  charles aranguiz      20    1989-04-17   35    1.71       Chile
#
#                         position   foot      joined contract_expires  \
# 31   Midfield - Central Midfield  right  2023-04-02       2025-06-30
# 646  Midfield - Central Midfield  right  2023-04-02       2025-06-30
#
#     outfitter  player_id  club_id country_of_birth city_of_birth
# 31       Nike      89701     6600            Chile   Puente Alto
# 646      Nike      89701     6600            Chile   Puente Alto

# %%
df_players[df_players['player_id'] == 982551]
# Out:
#         name  number date_of_birth  age  height citizenship  \
# 23   allison      42    2002-02-07   22    1.77      Brazil
# 639  allison      42    2002-02-07   22    1.77      Brazil
#
#                           position   foot      joined contract_expires  \
# 23   Midfield - Attacking Midfield  right  2023-01-31       2026-06-30
# 639  Midfield - Attacking Midfield  right  2023-01-31       2026-06-30
#
#     outfitter  player_id  club_id country_of_birth city_of_birth
# 23        NaN     982551     6600           Brazil  São Leopoldo
# 639       NaN     982551     6600           Brazil  São Leopoldo

# %%
df_players[df_players['player_id'] == 104505]
# Out:
#              name  number date_of_birth  age  height citizenship  \
# 24   alan patrick      10    1991-05-13   33    1.77      Brazil
# 641  alan patrick      10    1991-05-13   33    1.77      Brazil
#
#                           position   foot      joined contract_expires  \
# 24   Midfield - Attacking Midfield  right  2022-04-11       2026-12-31
# 641  Midfield - Attacking Midfield  right  2022-04-11       2026-12-31
#
#     outfitter  player_id  club_id country_of_birth city_of_birth
# 24     adidas     104505     6600           Brazil     São Paulo
# 641    adidas     104505     6600           Brazil     São Paulo

# %%
def mantener_primera_fila_valor_repetido(df, column_name):
    # Encuentra los índices de las filas duplicadas en la columna especificada
    duplicate_indices = df[df.duplicated(subset=[column_name], keep='first')].index
    
    # Elimina todas las filas duplicadas, excepto la primera ocurrencia
    df.drop(duplicate_indices[duplicate_indices != duplicate_indices[0]], inplace=True)

# %%
# Llama a la función para eliminar la siguiente fila de cada valor repetido en la columna 'B'
mantener_primera_fila_valor_repetido(df_players, 'player_id')

# %%
repeats(df_players,'player_id')
# Out:
# Valores repetidos en la columna 'player_id':
#   Valor '560417' se repite 2 veces en las filas [15, 630]

# %%
df_players[df_players['player_id'] == 560417]
# Out:
#        name  number date_of_birth  age  height citizenship  \
# 15   alemao      14    1998-04-01   26    1.82      Brazil
# 630  alemao      14    1998-04-01   26    1.82      Brazil
#
#                     position   foot      joined contract_expires outfitter  \
# 15   Attack - Centre-Forward  right  2023-07-17       2024-06-30      Nike
# 630  Attack - Centre-Forward  right  2023-07-17       2024-06-30      Nike
#
#      player_id  club_id country_of_birth city_of_birth
# 15      560417     6600           Brazil     Campo Erê
# 630     560417     6600           Brazil     Campo Erê

# %%
# Eliminar la fila según el índice
df_players = df_players.drop(630)

# Resetear el índice del DataFrame
df_players = df_players.reset_index(drop=True)

# %%
df_players[df_players['player_id'] == 560417]
# Out:
#       name  number date_of_birth  age  height citizenship  \
# 15  alemao      14    1998-04-01   26    1.82      Brazil
#
#                    position   foot      joined contract_expires outfitter  \
# 15  Attack - Centre-Forward  right  2023-07-17       2024-06-30      Nike
#
#     player_id  club_id country_of_birth city_of_birth
# 15     560417     6600           Brazil     Campo Erê

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1039 non-null   object
#  1   number            1039 non-null   int64
#  2   date_of_birth     1039 non-null   object
#  3   age               1039 non-null   int64
#  4   height            987 non-null    float64
#  5   citizenship       1039 non-null   object
#  6   position          1039 non-null   object
#  7   foot              977 non-null    object
#  8   joined            967 non-null    object
#  9   contract_expires  860 non-null    object
#  10  outfitter         563 non-null    object
#  11  player_id         1039 non-null   int32
#  12  club_id           1039 non-null   int64
#  13  country_of_birth  968 non-null    object
#  14  city_of_birth     968 non-null    object
# dtypes: float64(1), int32(1), int64(3), object(10)
# memory usage: 117.8+ KB

# %%
# Calcular el promedio de height por club_id
avg_height_by_club = df_players.groupby('club_id')['height'].transform('mean')

# Completar los valores nulos en la columna height con los promedios calculados
df_players['height'].fillna(avg_height_by_club, inplace=True)
# Out:
# C:\Users\Guille\AppData\Local\Temp\ipykernel_10412\1226349493.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_players['height'].fillna(avg_height_by_club, inplace=True)

# %%
# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
sns.countplot(x='foot', data=df_players, palette='viridis')

# Añadir título y etiquetas
plt.title('Cantidad de valores únicos por foot')
plt.xlabel('foot')
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
df_players['foot'].fillna('right', inplace=True)
# Out:
# C:\Users\Guille\AppData\Local\Temp\ipykernel_10412\3907491108.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_players['foot'].fillna('right', inplace=True)

# %%
# Seleccionar las columnas con datos numéricos
numeric_columns = df_players.select_dtypes(include='number')

# Imprimir el valor máximo y mínimo de cada columna numérica
for column in numeric_columns.columns:
    max_value = numeric_columns[column].max()
    min_value = numeric_columns[column].min()
    print(f'Columna {column}:')
    print(f'  Valor máximo: {max_value}')
    print(f'  Valor mínimo: {min_value}')
# Out:
# Columna number:
#   Valor máximo: 99
#   Valor mínimo: 0
# Columna age:
#   Valor máximo: 43
#   Valor mínimo: 17
# Columna height:
#   Valor máximo: 2.04
#   Valor mínimo: 1.6
# Columna player_id:
#   Valor máximo: 1196689
#   Valor mínimo: 13835
# Columna club_id:
#   Valor máximo: 28022
#   Valor mínimo: 199

# %%
df_players.to_csv('./Data/liga brasil/players.csv',index=False)

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
df_events = pd.read_csv('./Data/liga brasil/game_events.csv')
df_events.head()
# Out:
#             type  minute  game_id  player_id  club_id  \
# 0          Goals      70  4316187     875328    10010
# 1          Goals      72  4316187     674732     6600
# 2          Goals      83  4316187      51174     6600
# 3  Substitutions      46  4316187     982549     6600
# 4  Substitutions      46  4316187     388266    10010
#
#                                          description  player_in  player_assist
# 0  , Right-footed shot, 1. Goal of the Season Ass...          0         578872
# 1          , Left-footed shot, 1. Goal of the Season          0              0
# 2  , Header, 1. Goal of the Season Assist: , Corn...          0         277335
# 3                                         , Tactical     674732              0
# 4                                         , Tactical     162812              0

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           940 non-null    object
#  1   minute         940 non-null    int64
#  2   game_id        940 non-null    int64
#  3   player_id      940 non-null    int64
#  4   club_id        940 non-null    int64
#  5   description    940 non-null    object
#  6   player_in      940 non-null    int64
#  7   player_assist  940 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 58.9+ KB

# %%
# Seleccionar las columnas con datos numéricos
numeric_columns = df_events.select_dtypes(include='number')

# Imprimir el valor máximo y mínimo de cada columna numérica
for column in numeric_columns.columns:
    max_value = numeric_columns[column].max()
    min_value = numeric_columns[column].min()
    print(f'Columna {column}:')
    print(f'  Valor máximo: {max_value}')
    print(f'  Valor mínimo: {min_value}')
# Out:
# Columna minute:
#   Valor máximo: 90
#   Valor mínimo: 1
# Columna game_id:
#   Valor máximo: 4316315
#   Valor mínimo: 4316187
# Columna player_id:
#   Valor máximo: 1119009
#   Valor mínimo: 18829
# Columna club_id:
#   Valor máximo: 28022
#   Valor mínimo: 199
# Columna player_in:
#   Valor máximo: 1226150
#   Valor mínimo: 0
# Columna player_assist:
#   Valor máximo: 1084714
#   Valor mínimo: 0

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
def repet(df,columna):
    # Ahora, para encontrar los valores que se repiten en la columna 'columna', puedes usar el método value_counts() de pandas
    valores_repetidos = df[columna].value_counts()

    # Filtramos los valores que se repiten al menos una vez
    valores_repetidos = valores_repetidos[valores_repetidos > 1]

    print("Valores que se repiten en la columna 'columna':")
    print(valores_repetidos)

# %%
pd.set_option('display.max_columns', None)

# %%
df_games = pd.read_csv('./Data/data_normalizada/games.csv')
df_games.head()
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2321044             L1    2013   2. Matchday  2013-08-18            16
# 1  2321060             L1    2013   3. Matchday  2013-08-25            23
# 2  2321086             L1    2013   6. Matchday  2013-09-21             4
# 3  2321152             L1    2013  11. Matchday  2013-11-02            44
# 4  2321205             L1    2013  17. Matchday  2013-12-21            41
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 0            23                2                1                   1
# 1            24                0                2                  18
# 2            16                1                1                  15
# 3            33                0                2                   7
# 4            39                2                3                  14
#
#    away_club_position home_club_manager_name away_club_manager_name  \
# 0                  15           Jürgen Klopp   Torsten Lieberknecht
# 1                  11   Torsten Lieberknecht              Armin Veh
# 2                   1      Michael Wiesinger           Jürgen Klopp
# 3                   6            Jos Luhukay            Jens Keller
# 4                   9       Bert van Marwijk          Thomas Tuchel
#
#                  stadium  attendance          referee home_club_formation  \
# 0      SIGNAL IDUNA PARK       80200     Peter Sippel             4-2-3-1
# 1      EINTRACHT-Stadion       23325   Wolfgang Stark             4-3-2-1
# 2    Max-Morlock-Stadion       50000     Knut Kircher             4-2-3-1
# 3  Olympiastadion Berlin       69277      Günter Perl             4-2-3-1
# 4       Volksparkstadion       50000  Bastian Dankert             4-2-3-1
#
#   away_club_formation          home_club_name  \
# 0             4-3-2-1       Borussia Dortmund
# 1             4-2-3-1  Eintracht Braunschweig
# 2             4-2-3-1          1.FC Nuremberg
# 3             4-2-3-1              Hertha BSC
# 4       4-4-2 Diamond            Hamburger SV
#
#                          away_club_name aggregate competition_type
# 0                Eintracht Braunschweig       2:1  domestic_league
# 1        Eintracht Frankfurt Fußball AG       0:2  domestic_league
# 2                     Borussia Dortmund       1:1  domestic_league
# 3                         FC Schalke 04       0:2  domestic_league
# 4  1. Fußball- und Sportverein Mainz 05       2:3  domestic_league

# %%
repet(df_games,'game_id')
# Out:
# Valores que se repiten en la columna 'columna':
# Series([], Name: count, dtype: int64)

# %%
df_apperances = pd.read_csv('./Data/data_normalizada/appearances.csv')
df_apperances.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played
# 0      2        0              90
# 1      0        0              90
# 2      0        0              45
# 3      0        0              90
# 4      0        1              90

# %%
repet(df_apperances,'appearance_id')
# Out:
# Valores que se repiten en la columna 'columna':
# Series([], Name: count, dtype: int64)

# %%
df_club_games = pd.read_csv('./Data/data_normalizada/club_games.csv')
df_club_games.head()
# Out:
#    game_id  club_id  own_goals  own_position      own_manager_name  \
# 0  2320450     1468          0            -1     Holger Bachthaler
# 1  2320460        1          3            -1       Jürgen Luginger
# 2  2320472     2036          4            -1         Frank Schmidt
# 3  2321044       16          2             1          Jürgen Klopp
# 4  2321060       23          0            18  Torsten Lieberknecht
#
#    opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0           24               2                 -1             Armin Veh
# 1           86               1                 -1            Robin Dutt
# 2           72               5                 -1     Alexander Schmidt
# 3           23               1                 15  Torsten Lieberknecht
# 4           24               2                 11             Armin Veh
#
#   hosting  is_win
# 0    Home       0
# 1    Home       1
# 2    Home       0
# 3    Home       1
# 4    Home       0

# %%
df_clubs = pd.read_csv('./Data/data_normalizada/clubs.csv')
df_clubs.head()
# Out:
#    club_id                              name domestic_competition_id  \
# 0      105  Sportverein Darmstadt 1898 e. V.                      L1
# 1    11127             FK Ural Yekaterinburg                     RU1
# 2      114         Beşiktaş Jimnastik Kulübü                     TR1
# 3       12        Associazione Sportiva Roma                     IT1
# 4      148   Tottenham Hotspur Football Club                     GB1
#
#    squad_size  average_age  foreigners_number  foreigners_percentage  \
# 0          31         26.7                 11                   35.5
# 1          27         28.1                 15                   55.6
# 2          37         26.3                 17                   45.9
# 3          26         27.1                 18                   69.2
# 4          26         25.7                 20                   76.9
#
#    national_team_players                    stadium_name  stadium_seats  \
# 0                      1  Merck-Stadion am Böllenfalltor          17810
# 1                      6             Yekaterinburg Arena          23000
# 2                     14                 Tüpraş Stadyumu          42445
# 3                     16                Olimpico di Roma          73261
# 4                     20       Tottenham Hotspur Stadium          62850
#
#    net_transfer_record  last_season
# 0                 1.48         2023
# 1               895.00         2023
# 2                26.00         2023
# 3                63.20         2023
# 4               151.40         2023

# %%
repet(df_clubs,'club_id')
# Out:
# Valores que se repiten en la columna 'columna':
# Series([], Name: count, dtype: int64)

# %%
df_competitions = pd.read_csv('./Data/data_normalizada/competitions.csv')
df_competitions.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code confederation  \
# 0          75        Italy                  IT1        europa
# 1         122  Netherlands                  NL1        europa
# 2          56       Greece                  GR1        europa
# 3         136     Portugal                  PO1        europa
# 4         141       Russia                  RU1        europa
#
#    is_major_national_league
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False

# %%
df_competitions['competition_id'].unique()
# Out:
# array(['CIT', 'NLSC', 'GRP', 'POSU', 'RUSS', 'SUC', 'USC', 'DK1', 'EL',
#        'ES1', 'FR1', 'IT1', 'NL1', 'RUP', 'PO1', 'BESC', 'GB1', 'ELQ',
#        'CGB', 'DKP', 'ECLQ', 'FAC', 'NLP', 'UKRS', 'UKR1', 'CDR', 'CL',
#        'GR1', 'TR1', 'POCP', 'GBCS', 'KLUB', 'L1', 'RU1', 'SC1', 'SCI',
#        'BE1', 'CLQ', 'DFL', 'SFA', 'UKRP', 'DFB', 'FRCH'], dtype=object)

# %%
df_game_events = pd.read_csv('./Data/data_normalizada/game_events.csv')
df_game_events.head()
# Out:
#                       game_event_id        date  game_id  minute  \
# 0  2f41da30c471492e7d4a984951671677  2012-08-05  2211607      77
# 1  a72f7186d132775f234d3e2f7bc0ed5b  2012-08-05  2211607      77
# 2  b2d721eaed4692a5c59a92323689ef18  2012-08-05  2211607       3
# 3  aef768899cedac0c9a650980219075a2  2012-08-05  2211607      53
# 4  5d6d9533023057b6619ecd145a038bbe  2012-08-05  2211607      74
#
#             type  club_id  player_id  player_in_id  player_assist_id
# 0          Cards      610       4425            -1                -1
# 1          Cards      383      33210            -1                -1
# 2          Goals      383      36500            -1             56416
# 3          Goals      383      36500            -1            146258
# 4  Substitutions      383      36500         49499                -1

# %%
df_game_lineups = pd.read_csv('./Data/data_normalizada/game_lineups.csv')
df_game_lineups.head()
# Out:
#                     game_lineups_id        date  game_id  player_id  club_id  \
# 0  b2dbe01c3656b06c8e23e9de714e26bb  2013-07-27  2317258       1443      610
# 1  b50a3ec6d52fd1490aab42042ac4f738  2013-07-27  2317258       5017      610
# 2  7d890e6d0ff8af84b065839966a0ec81  2013-07-27  2317258       9602     1090
# 3  8c355268678b9bbc7084221b1f0fde36  2013-07-27  2317258      12282      610
# 4  76193074d549e5fdce4cdcbba0d66247  2013-07-27  2317258      25427     1090
#
#          player_name             type            position number  team_captain
# 0  Christian Poulsen      substitutes  Defensive Midfield      5             0
# 1   Niklas Moisander  starting_lineup         Centre-Back      4             0
# 2    Maarten Martens      substitutes         Left Winger     11             0
# 3        Daley Blind  starting_lineup           Left-Back     17             0
# 4        Roy Beerens  starting_lineup        Right Winger     23             0

# %%
repet(df_game_lineups,'game_id')
# Out:
# Valores que se repiten en la columna 'columna':
# game_id
# 2901276    53
# 3848893    52
# 3845102    52
# 3844812    52
# 3865513    52
#            ..
# 2614482     3
# 2487927     3
# 3224803     3
# 3224800     3
# 3905329     2
# Name: count, Length: 57568, dtype: int64

# %%
df_player_valuations = pd.read_csv('./Data/data_normalizada/player_valuations.csv')
df_player_valuations.head()
# Out:
#    player_id        date  market_value_in_eur  current_club_id  \
# 0     405973  2000-01-20               150000             3057
# 1     342216  2001-07-20               100000             1241
# 2       3132  2003-12-09               400000              126
# 3       6893  2003-12-15               900000              984
# 4         10  2004-10-04              7000000              398
#
#   player_club_domestic_competition_id
# 0                                 BE1
# 1                                 SC1
# 2                                 TR1
# 3                                 GB1
# 4                                 IT1

# %%
repet(df_player_valuations,'player_id')
# Out:
# Valores que se repiten en la columna 'columna':
# player_id
# 39153     52
# 35664     50
# 44162     50
# 57162     50
# 39381     49
#           ..
# 240063     2
# 542445     2
# 599678     2
# 415859     2
# 822900     2
# Name: count, Length: 28534, dtype: int64

# %%
df_players = pd.read_csv('./Data/data_normalizada/players.csv')
df_players.head()
# Out:
#    player_id                name  last_season  current_club_id  \
# 0         10      Miroslav Klose         2015              398
# 1         26  Roman Weidenfeller         2017               16
# 2         65    Dimitar Berbatov         2015             1091
# 3         77               Lúcio         2012              506
# 4         80          Tom Starke         2017               27
#
#           player_code    country_of_birth city_of_birth  \
# 0      miroslav-klose              Poland         Opole
# 1  roman-weidenfeller             Germany          Diez
# 2    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3               lucio              Brazil      Brasília
# 4          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship date_of_birth    sub_position    position   foot  \
# 0                Germany    1978-06-09  Centre-Forward      Attack  right
# 1                Germany    1980-08-06      Goalkeeper  Goalkeeper   left
# 2               Bulgaria    1981-01-30  Centre-Forward      Attack    NaN
# 3                 Brazil    1978-05-08     Centre-Back    Defender    NaN
# 4                Germany    1981-03-18      Goalkeeper  Goalkeeper  right
#
#    height_in_cm current_club_domestic_competition_id  \
# 0           184                                  IT1
# 1           190                                   L1
# 2             0                                  GR1
# 3             0                                  IT1
# 4           194                                   L1
#
#                                    current_club_name  market_value_in_eur  \
# 0                      Società Sportiva Lazio S.p.A.            1000000.0
# 1                                  Borussia Dortmund             750000.0
# 2  Panthessalonikios Athlitikos Omilos Konstantin...            1000000.0
# 3                             Juventus Football Club             200000.0
# 4                                  FC Bayern München             100000.0
#
#    highest_market_value_in_eur
# 0                   30000000.0
# 1                    8000000.0
# 2                   34500000.0
# 3                   24500000.0
# 4                    3000000.0

# %%
repet(df_players,'player_id')
# Out:
# Valores que se repiten en la columna 'columna':
# Series([], Name: count, dtype: int64)

# %%
df_players[df_players['player_id'] == 3132]
# Out:
#      player_id           name  last_season  current_club_id    player_code  \
# 145       3132  Florin Cernat         2013              126  florin-cernat
#
#     country_of_birth city_of_birth country_of_citizenship date_of_birth  \
# 145          Romania        Galaţi                Romania    1980-03-10
#
#            sub_position  position  foot  height_in_cm  \
# 145  Attacking Midfield  Midfield  left           168
#
#     current_club_domestic_competition_id       current_club_name  \
# 145                                  TR1  Çaykur Rizespor Kulübü
#
#      market_value_in_eur  highest_market_value_in_eur
# 145             100000.0                    2800000.0
